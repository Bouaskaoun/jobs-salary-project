# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('C:/Users/MedOvich/IdeaProjects/jobs-salary-project/data/glassdoor_jobs_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                          Job Title  \
# 0           0  BHJOB15656_16794 - Data Scientist
# 1           1                     Data Scientist
# 2           2                     Data Scientist
# 3           3                     Data Scientist
# 4           4              Junior Data Scientist
#
#                 Salary Estimate  \
# 0  $95K - $152K (Employer est.)
# 1  $95K - $152K (Employer est.)
# 2  $95K - $152K (Employer est.)
# 3  $95K - $152K (Employer est.)
# 4  $95K - $152K (Employer est.)
#
#                                      Job Description  Rating  \
# 0  The recruitment team here at Myticas is lookin...     3.7
# 1  *will work ONSITE 2-3 days each week\nThe data...     NaN
# 2  Qualifications:\n-10+ years experience with R,...     4.3
# 3  Company Description\n\nWe’re a six-time “Best ...     3.8
# 4  Responsibilities:\nWork with stakeholders to d...     NaN
#
#               Company Name      Location                  Size  Founded  \
# 0  Myticas Consulting\n3.7        Remote     1 to 50 Employees      NaN
# 1        Mint-Technologies  Richmond, VA     1 to 50 Employees      NaN
# 2        Infologitech\n4.3        Remote     1 to 50 Employees      NaN
# 3     Logic20/20 Inc.\n3.8   Seattle, WA  201 to 500 Employees   2005.0
# 4           Talentheed Inc        Remote                   NaN      NaN
#
#    Type of ownership                                 Industry  \
# 0  Company - Private  Information Technology Support Services
# 1  Company - Private                                      NaN
# 2  Company - Private  Information Technology Support Services
# 3  Company - Private                      Business Consulting
# 4                NaN                                      NaN
#
#                     Sector                   Revenue
# 0   Information Technology  Unknown / Non-Applicable
# 1                      NaN  Unknown / Non-Applicable
# 2   Information Technology    $1 to $5 million (USD)
# 3  Management & Consulting  $25 to $50 million (USD)
# 4                      NaN                       NaN

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue'],
#       dtype='object')

# %%
df[df['Salary Estimate'].isna()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Job Title, Salary Estimate, Job Description, Rating, Company Name, Location, Size, Founded, Type of ownership, Industry, Sector, Revenue, min_salary, max_salary]
# Index: []

# %%
salary = df['Salary Estimate'].apply(lambda x: x.split('(')[0].replace('K','').replace('$',''))
df[["min_salary", "max_salary"]] = salary.str.split("-").apply(pd.Series).ffill(axis=1)
df["min_salary"] = df["min_salary"].apply(lambda x: int(x))
df["max_salary"] = df["max_salary"].apply(lambda x: int(x))
df['avg_salary'] = (df["max_salary"] + df["min_salary"])/2

# %%
df.head()
# Out:
#    Unnamed: 0                          Job Title  \
# 0           0  BHJOB15656_16794 - Data Scientist
# 1           1                     Data Scientist
# 2           2                     Data Scientist
# 3           3                     Data Scientist
# 4           4              Junior Data Scientist
#
#                 Salary Estimate  \
# 0  $95K - $152K (Employer est.)
# 1  $95K - $152K (Employer est.)
# 2  $95K - $152K (Employer est.)
# 3  $95K - $152K (Employer est.)
# 4  $95K - $152K (Employer est.)
#
#                                      Job Description  Rating  \
# 0  The recruitment team here at Myticas is lookin...     3.7
# 1  *will work ONSITE 2-3 days each week\nThe data...     NaN
# 2  Qualifications:\n-10+ years experience with R,...     4.3
# 3  Company Description\n\nWe’re a six-time “Best ...     3.8
# 4  Responsibilities:\nWork with stakeholders to d...     NaN
#
#               Company Name      Location                  Size  Founded  \
# 0  Myticas Consulting\n3.7        Remote     1 to 50 Employees      NaN
# 1        Mint-Technologies  Richmond, VA     1 to 50 Employees      NaN
# 2        Infologitech\n4.3        Remote     1 to 50 Employees      NaN
# 3     Logic20/20 Inc.\n3.8   Seattle, WA  201 to 500 Employees   2005.0
# 4           Talentheed Inc        Remote                   NaN      NaN
#
#    Type of ownership                                 Industry  \
# 0  Company - Private  Information Technology Support Services
# 1  Company - Private                                      NaN
# 2  Company - Private  Information Technology Support Services
# 3  Company - Private                      Business Consulting
# 4                NaN                                      NaN
#
#                     Sector                   Revenue  min_salary  max_salary  \
# 0   Information Technology  Unknown / Non-Applicable          95         152
# 1                      NaN  Unknown / Non-Applicable          95         152
# 2   Information Technology    $1 to $5 million (USD)          95         152
# 3  Management & Consulting  $25 to $50 million (USD)          95         152
# 4                      NaN                       NaN          95         152
#
#    avg_salary
# 0       123.5
# 1       123.5
# 2       123.5
# 3       123.5
# 4       123.5

# %%
dups_color = df.pivot_table(columns=['min_salary'], aggfunc='size')
dups_color
# Out:
# min_salary
# 61     490
# 75     150
# 89      30
# 95      30
# 119    270
# 240     30
# dtype: int64

# %%
df.groupby(df.columns.tolist(),as_index=False).size()
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             3                                     Data Scientist
# 1             6                                     Data Scientist
# 2             7                                     Data Scientist
# 3             9                                     Data Scientist
# 4            11                                     Data Scientist
# ..          ...                                                ...
# 696         992  Senior or Staff Data Scientist, Spotify Advert...
# 697         995                 Data Scientist or Bioinformatician
# 698         996  Data Scientist / Senior Data Scientist - Globa...
# 699         997    decision scientist (multiple openings) - Remote
# 700         998                Junior Data Scientist, Supply Chain
#
#                   Salary Estimate  \
# 0    $95K - $152K (Employer est.)
# 1    $95K - $152K (Employer est.)
# 2    $95K - $152K (Employer est.)
# 3    $95K - $152K (Employer est.)
# 4    $95K - $152K (Employer est.)
# ..                            ...
# 696  $61K - $96K (Glassdoor est.)
# 697  $61K - $96K (Glassdoor est.)
# 698  $61K - $96K (Glassdoor est.)
# 699  $61K - $96K (Glassdoor est.)
# 700  $61K - $96K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 0    Company Description\n\nWe’re a six-time “Best ...     3.8
# 1    Who We’re Looking For\n\nToyota Motors North A...     3.9
# 2    Data Scientist\nLocation: 100% Remote\nHire ty...     4.6
# 3    Company Description\n\nSia Partners is a next-...     4.0
# 4    Job Title: Data Scientist\nJob Location: Denve...     3.6
# ..                                                 ...     ...
# 696  Data, Research & Insights\nData Science\nAt Sp...     4.2
# 697  Center Information:\nThe Quantitative Biomedic...     3.9
# 698  Description:\nThe Global Commercial Analytics ...     4.3
# 699  Job Posting\n: Jul 14, 2022\nJob Posting End D...     3.8
# 700  Location\nSingapore, Central Singapore\nPlanni...     4.3
#
#                                  Company Name       Location  \
# 0                        Logic20/20 Inc.\n3.8    Seattle, WA
# 1                                 Toyota\n3.9      Plano, TX
# 2                         Kani Solutions\n4.6         Remote
# 3                           Sia Partners\n4.0   New York, NY
# 4                          EXCELACOM INC\n3.6  Englewood, CO
# ..                                        ...            ...
# 696                              Spotify\n4.2   New York, NY
# 697       UT Southwestern Medical Center\n3.9         Remote
# 698                                 Amex\n4.3   New York, NY
# 699                            Starbucks\n3.8    Seattle, WA
# 700  DELL GLOBAL B.V. (SINGAPORE BRANCH)\n4.3     Marina, CA
#
#                         Size  Founded  Type of ownership  \
# 0       201 to 500 Employees   2005.0  Company - Private
# 1           10000+ Employees   1957.0   Company - Public
# 2       201 to 500 Employees   2009.0  Company - Private
# 3     1001 to 5000 Employees   1999.0  Company - Private
# 4        51 to 200 Employees   2000.0  Company - Private
# ..                       ...      ...                ...
# 696  5001 to 10000 Employees   2006.0   Company - Public
# 697         10000+ Employees   1943.0           Hospital
# 698         10000+ Employees   1850.0   Company - Public
# 699         10000+ Employees   1971.0   Company - Public
# 700         10000+ Employees   1984.0   Company - Public
#
#                                     Industry                      Sector  \
# 0                        Business Consulting     Management & Consulting
# 1     Transportation Equipment Manufacturing               Manufacturing
# 2    Information Technology Support Services      Information Technology
# 3                        Business Consulting     Management & Consulting
# 4                Telecommunications Services          Telecommunications
# ..                                       ...                         ...
# 696                  Internet & Web Services      Information Technology
# 697         Health Care Services & Hospitals                  Healthcare
# 698         Financial Transaction Processing          Financial Services
# 699                      Restaurants & Cafes  Restaurants & Food Service
# 700  Information Technology Support Services      Information Technology
#
#                         Revenue  min_salary  max_salary  avg_salary  size
# 0      $25 to $50 million (USD)          95         152       123.5     1
# 1            $10+ billion (USD)          95         152       123.5     1
# 2       $5 to $10 million (USD)          95         152       123.5     1
# 3    $100 to $500 million (USD)          95         152       123.5     1
# 4      Unknown / Non-Applicable          95         152       123.5     1
# ..                          ...         ...         ...         ...   ...
# 696    Unknown / Non-Applicable          61          96        78.5     1
# 697      $2 to $5 billion (USD)          61          96        78.5     1
# 698          $10+ billion (USD)          61          96        78.5     1
# 699          $10+ billion (USD)          61          96        78.5     1
# 700          $10+ billion (USD)          61          96        78.5     1
#
# [701 rows x 17 columns]
